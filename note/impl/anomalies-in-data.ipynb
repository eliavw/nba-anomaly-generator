# %% [markdown]
# # Basketball Anomaly Dataset
#
# For both Synth and ADMERCS.
#
# Based on our earliest idea of a demo dataset that would contain typical contextual anomalies which should be easy for MERCS to detect.

# %% [markdown]
# # Preliminaries

# %%
# (Optional) Black codeformatter (`pip install nb_black`) for jupyterlab. In jupyter notebook, this changes slightly.
# %load_ext lab_black

# %% [markdown]
# ## Imports

# %%
import nba_api
from nba_api.stats import endpoints
from nba_api.stats.static import players, teams

import pandas as pd
import numpy as np

# show all columns
pd.set_option("display.max_columns", None)

# %%
from nba_anomaly_generator.data import load_lal

from nba_anomaly_generator.anom import (
    insert_dependency_anomaly,
    insert_contextual_anomaly,
    insert_swap_anomaly,
    insert_transformation_anomaly,
    ft_to_m,
    lb_to_kg,
)

# %% [markdown]
# # Load Data

# %%
# loading dump
df = load_lal()
df.head()
# Out:
#   SEASON_ID TEAM_ABBREVIATION  PLAYER_ID                    PLAYER  NUM  \
# 0   2018-19               LAL    1628398                Kyle Kuzma    0
# 1   2018-19               LAL     203484  Kentavious Caldwell-Pope    1
# 2   2018-19               LAL    1628366                Lonzo Ball    2
# 3   2018-19               LAL    1628404                 Josh Hart    3
# 4   2018-19               LAL    1627936               Alex Caruso    4
#
#   POSITION HEIGHT  WEIGHT    BIRTH_DATE  PLAYER_AGE  GP  GS     MIN  FGM  \
# 0        F    6-9     220  JUL 24, 1995        23.0  70  68  2314.0  496
# 1        G    6-5     205  FEB 18, 1993        26.0  82  23  2035.0  325
# 2        G    6-6     190  OCT 27, 1997        21.0  47  45  1423.0  185
# 3        G    6-5     215  MAR 06, 1995        24.0  67  22  1715.0  189
# 4        G    6-5     186  FEB 28, 1994        25.0  25   4   531.0   77
#
#     FGA  FG_PCT  FG3M  FG3A  FG3_PCT  FTM  FTA  FT_PCT  REB  AST  STL  BLK  \
# 0  1087   0.456   128   422    0.303  188  250   0.752  382  178   41   26
# 1   756   0.430   151   435    0.347  137  158   0.867  238  110   73   13
# 2   456   0.406    75   228    0.329   20   48   0.417  251  255   69   19
# 3   464   0.407    92   274    0.336   55   80   0.688  248   93   64   40
# 4   173   0.445    24    50    0.480   51   64   0.797   67   77   24    9
#
#     PTS
# 0  1308
# 1   938
# 2   465
# 3   525
# 4   229

# %% [markdown]
# # Kinds Of Columns
#
# Highlighting the interesting columns for in the presentation.

# %% [markdown]
# ## Metadata

# %%
metadata_columns = [
    "SEASON_ID",
    "TEAM_ABBREVIATION",
    "PLAYER_ID",
    "PLAYER",
    "NUM",
    "POSITION",
    "HEIGHT",
    "WEIGHT",
    "BIRTH_DATE",
    "PLAYER_AGE",
]

df.head().style.applymap(
    lambda x: "background-color:orange", subset=pd.IndexSlice[:, metadata_columns]
)
# Out:
# <style  type="text/css" >
#     #T_c6990220_a028_11ea_8de1_dc5360e91c1drow0_col0 {
#             background-color: orange;
#         }    #T_c6990220_a028_11ea_8de1_dc5360e91c1drow0_col1 {
#             background-color: orange;
#         }    #T_c6990220_a028_11ea_8de1_dc5360e91c1drow0_col2 {
#             background-color: orange;
#         }    #T_c6990220_a028_11ea_8de1_dc5360e91c1drow0_col3 {
#             background-color: orange;
#         }    #T_c6990220_a028_11ea_8de1_dc5360e91c1drow0_col4 {
#             background-color: orange;
#         }    #T_c6990220_a028_11ea_8de1_dc5360e91c1drow0_col5 {
#             background-color: orange;
#         }    #T_c6990220_a028_11ea_8de1_dc5360e91c1drow0_col6 {
#             background-color: orange;
#         }    #T_c6990220_a028_11ea_8de1_dc5360e91c1drow0_col7 {
#             background-color: orange;
#         }    #T_c6990220_a028_11ea_8de1_dc5360e91c1drow0_col8 {
#             background-color: orange;
#         }    #T_c6990220_a028_11ea_8de1_dc5360e91c1drow0_col9 {
#             background-color: orange;
#         }    #T_c6990220_a028_11ea_8de1_dc5360e91c1drow1_col0 {
#             background-color: orange;
#         }    #T_c6990220_a028_11ea_8de1_dc5360e91c1drow1_col1 {
#             background-color: orange;
#         }    #T_c6990220_a028_11ea_8de1_dc5360e91c1drow1_col2 {
#             background-color: orange;
#         }    #T_c6990220_a028_11ea_8de1_dc5360e91c1drow1_col3 {
#             background-color: orange;
#         }    #T_c6990220_a028_11ea_8de1_dc5360e91c1drow1_col4 {
#             background-color: orange;
#         }    #T_c6990220_a028_11ea_8de1_dc5360e91c1drow1_col5 {
#             background-color: orange;
#         }    #T_c6990220_a028_11ea_8de1_dc5360e91c1drow1_col6 {
#             background-color: orange;
#         }    #T_c6990220_a028_11ea_8de1_dc5360e91c1drow1_col7 {
#             background-color: orange;
#         }    #T_c6990220_a028_11ea_8de1_dc5360e91c1drow1_col8 {
#             background-color: orange;
#         }    #T_c6990220_a028_11ea_8de1_dc5360e91c1drow1_col9 {
#             background-color: orange;
#         }    #T_c6990220_a028_11ea_8de1_dc5360e91c1drow2_col0 {
#             background-color: orange;
#         }    #T_c6990220_a028_11ea_8de1_dc5360e91c1drow2_col1 {
#             background-color: orange;
#         }    #T_c6990220_a028_11ea_8de1_dc5360e91c1drow2_col2 {
#             background-color: orange;
#         }    #T_c6990220_a028_11ea_8de1_dc5360e91c1drow2_col3 {
#             background-color: orange;
#         }    #T_c6990220_a028_11ea_8de1_dc5360e91c1drow2_col4 {
#             background-color: orange;
#         }    #T_c6990220_a028_11ea_8de1_dc5360e91c1drow2_col5 {
#             background-color: orange;
#         }    #T_c6990220_a028_11ea_8de1_dc5360e91c1drow2_col6 {
#             background-color: orange;
#         }    #T_c6990220_a028_11ea_8de1_dc5360e91c1drow2_col7 {
#             background-color: orange;
#         }    #T_c6990220_a028_11ea_8de1_dc5360e91c1drow2_col8 {
#             background-color: orange;
#         }    #T_c6990220_a028_11ea_8de1_dc5360e91c1drow2_col9 {
#             background-color: orange;
#         }    #T_c6990220_a028_11ea_8de1_dc5360e91c1drow3_col0 {
#             background-color: orange;
#         }    #T_c6990220_a028_11ea_8de1_dc5360e91c1drow3_col1 {
#             background-color: orange;
#         }    #T_c6990220_a028_11ea_8de1_dc5360e91c1drow3_col2 {
#             background-color: orange;
#         }    #T_c6990220_a028_11ea_8de1_dc5360e91c1drow3_col3 {
#             background-color: orange;
#         }    #T_c6990220_a028_11ea_8de1_dc5360e91c1drow3_col4 {
#             background-color: orange;
#         }    #T_c6990220_a028_11ea_8de1_dc5360e91c1drow3_col5 {
#             background-color: orange;
#         }    #T_c6990220_a028_11ea_8de1_dc5360e91c1drow3_col6 {
#             background-color: orange;
#         }    #T_c6990220_a028_11ea_8de1_dc5360e91c1drow3_col7 {
#             background-color: orange;
#         }    #T_c6990220_a028_11ea_8de1_dc5360e91c1drow3_col8 {
#             background-color: orange;
#         }    #T_c6990220_a028_11ea_8de1_dc5360e91c1drow3_col9 {
#             background-color: orange;
#         }    #T_c6990220_a028_11ea_8de1_dc5360e91c1drow4_col0 {
#             background-color: orange;
#         }    #T_c6990220_a028_11ea_8de1_dc5360e91c1drow4_col1 {
#             background-color: orange;
#         }    #T_c6990220_a028_11ea_8de1_dc5360e91c1drow4_col2 {
#             background-color: orange;
#         }    #T_c6990220_a028_11ea_8de1_dc5360e91c1drow4_col3 {
#             background-color: orange;
#         }    #T_c6990220_a028_11ea_8de1_dc5360e91c1drow4_col4 {
#             background-color: orange;
#         }    #T_c6990220_a028_11ea_8de1_dc5360e91c1drow4_col5 {
#             background-color: orange;
#         }    #T_c6990220_a028_11ea_8de1_dc5360e91c1drow4_col6 {
#             background-color: orange;
#         }    #T_c6990220_a028_11ea_8de1_dc5360e91c1drow4_col7 {
#             background-color: orange;
#         }    #T_c6990220_a028_11ea_8de1_dc5360e91c1drow4_col8 {
#             background-color: orange;
#         }    #T_c6990220_a028_11ea_8de1_dc5360e91c1drow4_col9 {
#             background-color: orange;
#         }</style><table id="T_c6990220_a028_11ea_8de1_dc5360e91c1d" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >SEASON_ID</th>        <th class="col_heading level0 col1" >TEAM_ABBREVIATION</th>        <th class="col_heading level0 col2" >PLAYER_ID</th>        <th class="col_heading level0 col3" >PLAYER</th>        <th class="col_heading level0 col4" >NUM</th>        <th class="col_heading level0 col5" >POSITION</th>        <th class="col_heading level0 col6" >HEIGHT</th>        <th class="col_heading level0 col7" >WEIGHT</th>        <th class="col_heading level0 col8" >BIRTH_DATE</th>        <th class="col_heading level0 col9" >PLAYER_AGE</th>        <th class="col_heading level0 col10" >GP</th>        <th class="col_heading level0 col11" >GS</th>        <th class="col_heading level0 col12" >MIN</th>        <th class="col_heading level0 col13" >FGM</th>        <th class="col_heading level0 col14" >FGA</th>        <th class="col_heading level0 col15" >FG_PCT</th>        <th class="col_heading level0 col16" >FG3M</th>        <th class="col_heading level0 col17" >FG3A</th>        <th class="col_heading level0 col18" >FG3_PCT</th>        <th class="col_heading level0 col19" >FTM</th>        <th class="col_heading level0 col20" >FTA</th>        <th class="col_heading level0 col21" >FT_PCT</th>        <th class="col_heading level0 col22" >REB</th>        <th class="col_heading level0 col23" >AST</th>        <th class="col_heading level0 col24" >STL</th>        <th class="col_heading level0 col25" >BLK</th>        <th class="col_heading level0 col26" >PTS</th>        <th class="col_heading level0 col27" >a_lbl</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c6990220_a028_11ea_8de1_dc5360e91c1dlevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_c6990220_a028_11ea_8de1_dc5360e91c1drow0_col0" class="data row0 col0" >2018-19</td>
#                         <td id="T_c6990220_a028_11ea_8de1_dc5360e91c1drow0_col1" class="data row0 col1" >LAL</td>
#                         <td id="T_c6990220_a028_11ea_8de1_dc5360e91c1drow0_col2" class="data row0 col2" >1628398</td>
#                         <td id="T_c6990220_a028_11ea_8de1_dc5360e91c1drow0_col3" class="data row0 col3" >Kyle Kuzma</td>
#                         <td id="T_c6990220_a028_11ea_8de1_dc5360e91c1drow0_col4" class="data row0 col4" >0</td>
#                         <td id="T_c6990220_a028_11ea_8de1_dc5360e91c1drow0_col5" class="data row0 col5" >F</td>
#                         <td id="T_c6990220_a028_11ea_8de1_dc5360e91c1drow0_col6" class="data row0 col6" >6-9</td>
#                         <td id="T_c6990220_a028_11ea_8de1_dc5360e91c1drow0_col7" class="data row0 col7" >220</td>
#                         <td id="T_c6990220_a028_11ea_8de1_dc5360e91c1drow0_col8" class="data row0 co

# %% [markdown]
# ## Stats

# %%
stats_columns = [
    "GP",
    "GS",
    "MIN",
    "FGM",
    "FGA",
    # "FG_PCT",
    "FG3M",
    "FG3A",
    # "FG3_PCT",
    "FTM",
    "FTA",
    # "FT_PCT",
    # "OREB",
    # "DREB",
    "REB",
    "AST",
    "STL",
    "BLK",
    # "TOV",
    # "PF",
    "PTS",
]

df.head().style.applymap(
    lambda x: "background-color:orange", subset=pd.IndexSlice[:, stats_columns]
)
# Out:
# <style  type="text/css" >
#     #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow0_col10 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow0_col11 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow0_col12 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow0_col13 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow0_col14 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow0_col16 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow0_col17 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow0_col19 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow0_col20 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow0_col22 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow0_col23 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow0_col24 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow0_col25 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow0_col26 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow1_col10 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow1_col11 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow1_col12 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow1_col13 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow1_col14 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow1_col16 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow1_col17 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow1_col19 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow1_col20 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow1_col22 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow1_col23 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow1_col24 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow1_col25 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow1_col26 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow2_col10 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow2_col11 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow2_col12 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow2_col13 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow2_col14 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow2_col16 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow2_col17 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow2_col19 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow2_col20 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow2_col22 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow2_col23 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow2_col24 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow2_col25 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow2_col26 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow3_col10 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow3_col11 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow3_col12 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow3_col13 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow3_col14 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow3_col16 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow3_col17 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow3_col19 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow3_col20 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow3_col22 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow3_col23 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow3_col24 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow3_col25 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow3_col26 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow4_col10 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow4_col11 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow4_col12 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow4_col13 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow4_col14 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow4_col16 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow4_col17 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow4_col19 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow4_col20 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow4_col22 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow4_col23 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow4_col24 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow4_col25 {
#             background-color: orange;
#         }    #T_c3abefdc_a028_11ea_8de1_dc5360e91c1drow4_col26 {
#             background-color: orange;
#         }</style><table id="T_c3abefdc_a028_11ea_8de1_dc5360e91c1d" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >SEASON_ID</th>        <th class="col_heading level0 col1" >TEAM_ABBREVIATION</th>        <th class="col_heading level0 col2" >PLAYER_ID</th>        <th class="col_heading level0 col3" >PLAYER</th>        <th class="col_heading level0 col4" >NUM</th>        <th class="col_heading level0 col5" >POSITION</th>        <th class="col_heading level0 col6" >HEIGHT</th>        <th class="col_heading level0 col7" >WEIGHT</th>        <th class="col_heading level0 col8" >BIRTH_DATE</th>        <th class="col_heading level0 col9" >PLAYER_AGE</th>        <th class="col_heading level0 col10" >GP</th>        <th c

# %% [markdown]
# ## Derived Stats

# %%
derived_stats_columns = [
    "FG_PCT",
    "FG3_PCT",
    "FT_PCT",
]

df.head().style.applymap(
    lambda x: "background-color:orange", subset=pd.IndexSlice[:, derived_stats_columns]
)
# Out:
# <style  type="text/css" >
#     #T_c051ef1c_a028_11ea_8de1_dc5360e91c1drow0_col15 {
#             background-color: orange;
#         }    #T_c051ef1c_a028_11ea_8de1_dc5360e91c1drow0_col18 {
#             background-color: orange;
#         }    #T_c051ef1c_a028_11ea_8de1_dc5360e91c1drow0_col21 {
#             background-color: orange;
#         }    #T_c051ef1c_a028_11ea_8de1_dc5360e91c1drow1_col15 {
#             background-color: orange;
#         }    #T_c051ef1c_a028_11ea_8de1_dc5360e91c1drow1_col18 {
#             background-color: orange;
#         }    #T_c051ef1c_a028_11ea_8de1_dc5360e91c1drow1_col21 {
#             background-color: orange;
#         }    #T_c051ef1c_a028_11ea_8de1_dc5360e91c1drow2_col15 {
#             background-color: orange;
#         }    #T_c051ef1c_a028_11ea_8de1_dc5360e91c1drow2_col18 {
#             background-color: orange;
#         }    #T_c051ef1c_a028_11ea_8de1_dc5360e91c1drow2_col21 {
#             background-color: orange;
#         }    #T_c051ef1c_a028_11ea_8de1_dc5360e91c1drow3_col15 {
#             background-color: orange;
#         }    #T_c051ef1c_a028_11ea_8de1_dc5360e91c1drow3_col18 {
#             background-color: orange;
#         }    #T_c051ef1c_a028_11ea_8de1_dc5360e91c1drow3_col21 {
#             background-color: orange;
#         }    #T_c051ef1c_a028_11ea_8de1_dc5360e91c1drow4_col15 {
#             background-color: orange;
#         }    #T_c051ef1c_a028_11ea_8de1_dc5360e91c1drow4_col18 {
#             background-color: orange;
#         }    #T_c051ef1c_a028_11ea_8de1_dc5360e91c1drow4_col21 {
#             background-color: orange;
#         }</style><table id="T_c051ef1c_a028_11ea_8de1_dc5360e91c1d" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >SEASON_ID</th>        <th class="col_heading level0 col1" >TEAM_ABBREVIATION</th>        <th class="col_heading level0 col2" >PLAYER_ID</th>        <th class="col_heading level0 col3" >PLAYER</th>        <th class="col_heading level0 col4" >NUM</th>        <th class="col_heading level0 col5" >POSITION</th>        <th class="col_heading level0 col6" >HEIGHT</th>        <th class="col_heading level0 col7" >WEIGHT</th>        <th class="col_heading level0 col8" >BIRTH_DATE</th>        <th class="col_heading level0 col9" >PLAYER_AGE</th>        <th class="col_heading level0 col10" >GP</th>        <th class="col_heading level0 col11" >GS</th>        <th class="col_heading level0 col12" >MIN</th>        <th class="col_heading level0 col13" >FGM</th>        <th class="col_heading level0 col14" >FGA</th>        <th class="col_heading level0 col15" >FG_PCT</th>        <th class="col_heading level0 col16" >FG3M</th>        <th class="col_heading level0 col17" >FG3A</th>        <th class="col_heading level0 col18" >FG3_PCT</th>        <th class="col_heading level0 col19" >FTM</th>        <th class="col_heading level0 col20" >FTA</th>        <th class="col_heading level0 col21" >FT_PCT</th>        <th class="col_heading level0 col22" >REB</th>        <th class="col_heading level0 col23" >AST</th>        <th class="col_heading level0 col24" >STL</th>        <th class="col_heading level0 col25" >BLK</th>        <th class="col_heading level0 col26" >PTS</th>        <th class="col_heading level0 col27" >a_lbl</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c051ef1c_a028_11ea_8de1_dc5360e91c1dlevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_c051ef1c_a028_11ea_8de1_dc5360e91c1drow0_col0" class="data row0 col0" >2018-19</td>
#                         <td id="T_c051ef1c_a028_11ea_8de1_dc5360e91c1drow0_col1" class="data row0 col1" >LAL</td>
#                         <td id="T_c051ef1c_a028_11ea_8de1_dc5360e91c1drow0_col2" class="data row0 col2" >1628398</td>
#                         <td id="T_c051ef1c_a028_11ea_8de1_dc5360e91c1drow0_col3" class="data row0 col3" >Kyle Kuzma</td>
#                         <td id="T_c051ef1c_a028_11ea_8de1_dc5360e91c1drow0_col4" class="data row0 col4" >0</td>
#                         <td id="T_c051ef1c_a028_11ea_8de1_dc5360e91c1drow0_col5" class="data row0 col5" >F</td>
#                         <td id="T_c051ef1c_a028_11ea_8de1_dc5360e91c1drow0_col6" class="data row0 col6" >6-9</td>
#                         <td id="T_c051ef1c_a028_11ea_8de1_dc5360e91c1drow0_col7" class="data row0 col7" >220</td>
#                         <td id="T_c051ef1c_a028_11ea_8de1_dc5360e91c1drow0_col8" class="data row0 col8" >JUL 24, 1995</td>
#                         <td id="T_c051ef1c_a028_11ea_8de1_dc5360e91c1drow0_col9" class="data row0 col9" >23.00</td>
#                         <td id="T_c051ef1c_a028_11ea_8de1_dc5360e91c1drow0_col10" class="data row0 col10" >70</td>
#                         <td id="T_c051ef1c_a028_11ea_8de1_dc5360e91c1drow0_col11" class="data row0 col11" >68</td>
#                         <td id="T_c051ef1c_a028_11ea_8de1_dc5360e91c1drow0_col12" class="data row0 col12" >2314.00</td>
#                         <td id="T_c051ef1c_a028_11ea_8de1_dc5360e91c1drow0_col13" class="data row0 col13" >496</td>
#                         <td id="T_c051ef1c_a028_11ea_8de1_dc5360e91c1drow0_col14" class="data row0 col14" >1087</td>
#                         <td id="T_c051ef1c_a028_11ea_8de1_dc5360e91c1drow0_col15" class="data row0 col15" >0.46</td>
#                         <td id="T_c051ef1c_a028_11ea_8de1_dc5360e91c1drow0_col16" class="data row0 col16" >128</td>
#                         <td id="T_c051ef1c_a028_11ea_8de1_dc5360e91c1drow0_col17" class="data row0 col17" >422</td>
#                         <td id="T_c051ef1c_a028_11ea_8de1_dc5360e91c1drow0_col18" class="data row0 col18" >0.30</td>
#                         <td id="T_c051ef1c_a028_11ea_8de1_dc5360e91c1drow0_col19" class="data row0 col19" >188</td>
#                         <td id="T_c051ef1c_a028_11ea_8de1_dc5360e91c1drow0_col20" class="data row0 col20" >250</td>
#                         <td id="T_c051ef1c_a028_11ea_8de1_dc5360e91c1drow0_col21" class="data row0 col21" >0.75</td>
#                         <td id="T_c051ef1c_a028_11ea_8de1_dc5360e91c1drow0_col22" class="data row0 col22" >382</td>
#                         <td id="T_c051ef1c_a028_11ea_8de1_dc5360e91c1drow0_col23" class="data row0 col23" >178</td>
#                         <td id="T_c051ef1c_a028_11ea_8de1_dc5360e91c1drow0_col24" class="data row0 col24" >41</td>
#                         <td id="T_c051ef1c_a028_11ea_8de1_dc5360e91c1drow0_col25" class="data row0 col25" >26</td>
#                         <td id="T_c051ef1c_a028_11ea_8de1_dc5360e91c1drow0_col26" class="data row0 col26" >1308</td>
#                         <td id="T_c051ef1c_a028_11ea_8de1_dc5360e91c1drow0_col27" class="data row0 col27" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_c051ef1c_a028_11ea_8de1_dc5360e91c1dlevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_c051ef1c_a028_11ea_8de1_dc5360e91c1drow1_col0" class="data row1 col0" >2018-19</td>
#                         <td id="T_c051ef1c_a028_11ea_8de1_dc5360e91c1drow1_col1" class="data row1 col1" >LAL</td>
#                         <td id="T_c051ef1c_a028_11ea_8de1_dc5360e91c1drow1_col2" class="data row1 col2" >203484</td>
#                         <td id="T_c051ef1c_a028_11ea_8de1_dc5360e91c1drow1_col3" class="data row1 col3" >Kentavious Caldwell-Pope</td>
#                         <td id="T_c051ef1c_a028_11ea_8de1_dc5360e91c1drow1_col4" class="data row1 col4" >1</td>
#                         <td id="T_c051ef1c_a028_11ea_8de1_dc5360e91c1drow1_col5" class="data row1 col5" >G</td>
#                         <td id="T_c051ef1c_a028_11ea_8de1_dc5360e91c1drow1_col6" class="data row1 col6" >6-5</td>
#                         <td id="T_c051ef1c_a028_11ea_8de1_dc5360e91c1drow1_col7" class="data row1 col7" >205</td>
#                         <td id="T_c051ef1c_a028_11ea_8de1_dc5360e91c1drow1_col8" class="data row1 col8" >FEB 18, 1993</td>
#                         <td id="T_c051ef1c_a028_11ea_8de1_dc5360e91c1drow1_col9" class="data row1 col9" >26.

# %% [markdown]
# ## All together

# %%
pd.set_option("precision", 2)

df.head().style.applymap(
    lambda x: "background-color:lightblue", subset=pd.IndexSlice[:, metadata_columns]
).applymap(
    lambda x: "background-color:orange", subset=pd.IndexSlice[:, stats_columns]
).applymap(
    lambda x: "background-color:yellow", subset=pd.IndexSlice[:, derived_stats_columns],
)
# Out:
# <style  type="text/css" >
#     #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow0_col0 {
#             background-color: lightblue;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow0_col1 {
#             background-color: lightblue;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow0_col2 {
#             background-color: lightblue;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow0_col3 {
#             background-color: lightblue;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow0_col4 {
#             background-color: lightblue;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow0_col5 {
#             background-color: lightblue;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow0_col6 {
#             background-color: lightblue;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow0_col7 {
#             background-color: lightblue;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow0_col8 {
#             background-color: lightblue;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow0_col9 {
#             background-color: lightblue;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow0_col10 {
#             background-color: orange;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow0_col11 {
#             background-color: orange;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow0_col12 {
#             background-color: orange;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow0_col13 {
#             background-color: orange;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow0_col14 {
#             background-color: orange;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow0_col15 {
#             background-color: yellow;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow0_col16 {
#             background-color: orange;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow0_col17 {
#             background-color: orange;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow0_col18 {
#             background-color: yellow;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow0_col19 {
#             background-color: orange;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow0_col20 {
#             background-color: orange;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow0_col21 {
#             background-color: yellow;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow0_col22 {
#             background-color: orange;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow0_col23 {
#             background-color: orange;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow0_col24 {
#             background-color: orange;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow0_col25 {
#             background-color: orange;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow0_col26 {
#             background-color: orange;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow1_col0 {
#             background-color: lightblue;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow1_col1 {
#             background-color: lightblue;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow1_col2 {
#             background-color: lightblue;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow1_col3 {
#             background-color: lightblue;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow1_col4 {
#             background-color: lightblue;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow1_col5 {
#             background-color: lightblue;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow1_col6 {
#             background-color: lightblue;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow1_col7 {
#             background-color: lightblue;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow1_col8 {
#             background-color: lightblue;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow1_col9 {
#             background-color: lightblue;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow1_col10 {
#             background-color: orange;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow1_col11 {
#             background-color: orange;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow1_col12 {
#             background-color: orange;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow1_col13 {
#             background-color: orange;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow1_col14 {
#             background-color: orange;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow1_col15 {
#             background-color: yellow;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow1_col16 {
#             background-color: orange;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow1_col17 {
#             background-color: orange;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow1_col18 {
#             background-color: yellow;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow1_col19 {
#             background-color: orange;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow1_col20 {
#             background-color: orange;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow1_col21 {
#             background-color: yellow;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow1_col22 {
#             background-color: orange;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow1_col23 {
#             background-color: orange;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow1_col24 {
#             background-color: orange;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow1_col25 {
#             background-color: orange;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow1_col26 {
#             background-color: orange;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow2_col0 {
#             background-color: lightblue;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow2_col1 {
#             background-color: lightblue;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow2_col2 {
#             background-color: lightblue;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow2_col3 {
#             background-color: lightblue;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow2_col4 {
#             background-color: lightblue;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow2_col5 {
#             background-color: lightblue;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow2_col6 {
#             background-color: lightblue;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow2_col7 {
#             background-color: lightblue;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow2_col8 {
#             background-color: lightblue;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow2_col9 {
#             background-color: lightblue;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow2_col10 {
#             background-color: orange;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow2_col11 {
#             background-color: orange;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow2_col12 {
#             background-color: orange;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow2_col13 {
#             background-color: orange;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow2_col14 {
#             background-color: orange;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow2_col15 {
#             background-color: yellow;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow2_col16 {
#             background-color: orange;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow2_col17 {
#             background-color: orange;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow2_col18 {
#             background-color: yellow;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow2_col19 {
#             background-color: orange;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow2_col20 {
#             background-color: orange;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow2_col21 {
#             background-color: yellow;
#         }    #T_bc518b66_a028_11ea_8de1_dc5360e91c1drow2_col22 {
#             background-color:

# %% [markdown]
# # Insert Anomalies

# %% [markdown]
# ## Dependency Anomaly

# %%
df, md = insert_dependency_anomaly(
    df,
    row=None,
    col="PLAYER_AGE",
    val=None,
    val_list=None,
    val_dist=None,
    random_state=420,
    rng=None,
)

df.head()
# Out:
#   SEASON_ID TEAM_ABBREVIATION  PLAYER_ID                    PLAYER  NUM  \
# 0   2018-19               LAL    1628398                Kyle Kuzma    0
# 1   2018-19               LAL     203484  Kentavious Caldwell-Pope    1
# 2   2018-19               LAL    1628366                Lonzo Ball    2
# 3   2018-19               LAL    1628404                 Josh Hart    3
# 4   2018-19               LAL    1627936               Alex Caruso    4
#
#   POSITION HEIGHT  WEIGHT    BIRTH_DATE  PLAYER_AGE  GP  GS     MIN  FGM  \
# 0        F    6-9     220  JUL 24, 1995        23.0  70  68  2314.0  496
# 1        G    6-5     205  FEB 18, 1993        26.0  82  23  2035.0  325
# 2        G    6-6     190  OCT 27, 1997        21.0  47  45  1423.0  185
# 3        G    6-5     215  MAR 06, 1995        24.0  67  22  1715.0  189
# 4        G    6-5     186  FEB 28, 1994        25.0  25   4   531.0   77
#
#     FGA  FG_PCT  FG3M  FG3A  FG3_PCT  FTM  FTA  FT_PCT  REB  AST  STL  BLK  \
# 0  1087    0.46   128   422     0.30  188  250    0.75  382  178   41   26
# 1   756    0.43   151   435     0.35  137  158    0.87  238  110   73   13
# 2   456    0.41    75   228     0.33   20   48    0.42  251  255   69   19
# 3   464    0.41    92   274     0.34   55   80    0.69  248   93   64   40
# 4   173    0.45    24    50     0.48   51   64    0.80   67   77   24    9
#
#     PTS  a_lbl
# 0  1308      0
# 1   938      0
# 2   465      0
# 3   525      0
# 4   229      0

# %%
md
# Out:
# {'iloc': (10, 9), 'loc': (10, 'PLAYER_AGE'), 'old': 21.0, 'new': 28.0}

# %%
df.tail(7).style.applymap(
    lambda x: "background-color:red", subset=pd.IndexSlice[md["loc"]]
)
# Out:
# <style  type="text/css" >
#     #T_d91398f2_a028_11ea_8de1_dc5360e91c1drow0_col9 {
#             background-color: red;
#         }</style><table id="T_d91398f2_a028_11ea_8de1_dc5360e91c1d" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >SEASON_ID</th>        <th class="col_heading level0 col1" >TEAM_ABBREVIATION</th>        <th class="col_heading level0 col2" >PLAYER_ID</th>        <th class="col_heading level0 col3" >PLAYER</th>        <th class="col_heading level0 col4" >NUM</th>        <th class="col_heading level0 col5" >POSITION</th>        <th class="col_heading level0 col6" >HEIGHT</th>        <th class="col_heading level0 col7" >WEIGHT</th>        <th class="col_heading level0 col8" >BIRTH_DATE</th>        <th class="col_heading level0 col9" >PLAYER_AGE</th>        <th class="col_heading level0 col10" >GP</th>        <th class="col_heading level0 col11" >GS</th>        <th class="col_heading level0 col12" >MIN</th>        <th class="col_heading level0 col13" >FGM</th>        <th class="col_heading level0 col14" >FGA</th>        <th class="col_heading level0 col15" >FG_PCT</th>        <th class="col_heading level0 col16" >FG3M</th>        <th class="col_heading level0 col17" >FG3A</th>        <th class="col_heading level0 col18" >FG3_PCT</th>        <th class="col_heading level0 col19" >FTM</th>        <th class="col_heading level0 col20" >FTA</th>        <th class="col_heading level0 col21" >FT_PCT</th>        <th class="col_heading level0 col22" >REB</th>        <th class="col_heading level0 col23" >AST</th>        <th class="col_heading level0 col24" >STL</th>        <th class="col_heading level0 col25" >BLK</th>        <th class="col_heading level0 col26" >PTS</th>        <th class="col_heading level0 col27" >a_lbl</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_d91398f2_a028_11ea_8de1_dc5360e91c1dlevel0_row0" class="row_heading level0 row0" >10</th>
#                         <td id="T_d91398f2_a028_11ea_8de1_dc5360e91c1drow0_col0" class="data row0 col0" >2018-19</td>
#                         <td id="T_d91398f2_a028_11ea_8de1_dc5360e91c1drow0_col1" class="data row0 col1" >LAL</td>
#                         <td id="T_d91398f2_a028_11ea_8de1_dc5360e91c1drow0_col2" class="data row0 col2" >1627742</td>
#                         <td id="T_d91398f2_a028_11ea_8de1_dc5360e91c1drow0_col3" class="data row0 col3" >Brandon Ingram</td>
#                         <td id="T_d91398f2_a028_11ea_8de1_dc5360e91c1drow0_col4" class="data row0 col4" >14</td>
#                         <td id="T_d91398f2_a028_11ea_8de1_dc5360e91c1drow0_col5" class="data row0 col5" >F</td>
#                         <td id="T_d91398f2_a028_11ea_8de1_dc5360e91c1drow0_col6" class="data row0 col6" >6-9</td>
#                         <td id="T_d91398f2_a028_11ea_8de1_dc5360e91c1drow0_col7" class="data row0 col7" >190</td>
#                         <td id="T_d91398f2_a028_11ea_8de1_dc5360e91c1drow0_col8" class="data row0 col8" >SEP 02, 1997</td>
#                         <td id="T_d91398f2_a028_11ea_8de1_dc5360e91c1drow0_col9" class="data row0 col9" >28.00</td>
#                         <td id="T_d91398f2_a028_11ea_8de1_dc5360e91c1drow0_col10" class="data row0 col10" >52</td>
#                         <td id="T_d91398f2_a028_11ea_8de1_dc5360e91c1drow0_col11" class="data row0 col11" >52</td>
#                         <td id="T_d91398f2_a028_11ea_8de1_dc5360e91c1drow0_col12" class="data row0 col12" >1761.00</td>
#                         <td id="T_d91398f2_a028_11ea_8de1_dc5360e91c1drow0_col13" class="data row0 col13" >362</td>
#                         <td id="T_d91398f2_a028_11ea_8de1_dc5360e91c1drow0_col14" class="data row0 col14" >729</td>
#                         <td id="T_d91398f2_a028_11ea_8de1_dc5360e91c1drow0_col15" class="data row0 col15" >0.50</td>
#                         <td id="T_d91398f2_a028_11ea_8de1_dc5360e91c1drow0_col16" class="data row0 col16" >31</td>
#                         <td id="T_d91398f2_a028_11ea_8de1_dc5360e91c1drow0_col17" class="data row0 col17" >94</td>
#                         <td id="T_d91398f2_a028_11ea_8de1_dc5360e91c1drow0_col18" class="data row0 col18" >0.33</td>
#                         <td id="T_d91398f2_a028_11ea_8de1_dc5360e91c1drow0_col19" class="data row0 col19" >195</td>
#                         <td id="T_d91398f2_a028_11ea_8de1_dc5360e91c1drow0_col20" class="data row0 col20" >289</td>
#                         <td id="T_d91398f2_a028_11ea_8de1_dc5360e91c1drow0_col21" class="data row0 col21" >0.68</td>
#                         <td id="T_d91398f2_a028_11ea_8de1_dc5360e91c1drow0_col22" class="data row0 col22" >267</td>
#                         <td id="T_d91398f2_a028_11ea_8de1_dc5360e91c1drow0_col23" class="data row0 col23" >154</td>
#                         <td id="T_d91398f2_a028_11ea_8de1_dc5360e91c1drow0_col24" class="data row0 col24" >28</td>
#                         <td id="T_d91398f2_a028_11ea_8de1_dc5360e91c1drow0_col25" class="data row0 col25" >31</td>
#                         <td id="T_d91398f2_a028_11ea_8de1_dc5360e91c1drow0_col26" class="data row0 col26" >950</td>
#                         <td id="T_d91398f2_a028_11ea_8de1_dc5360e91c1drow0_col27" class="data row0 col27" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_d91398f2_a028_11ea_8de1_dc5360e91c1dlevel0_row1" class="row_heading level0 row1" >11</th>
#                         <td id="T_d91398f2_a028_11ea_8de1_dc5360e91c1drow1_col0" class="data row1 col0" >2018-19</td>
#                         <td id="T_d91398f2_a028_11ea_8de1_dc5360e91c1drow1_col1" class="data row1 col1" >LAL</td>
#                         <td id="T_d91398f2_a028_11ea_8de1_dc5360e91c1drow1_col2" class="data row1 col2" >1629021</td>
#                         <td id="T_d91398f2_a028_11ea_8de1_dc5360e91c1drow1_col3" class="data row1 col3" >Moritz Wagner</td>
#                         <td id="T_d91398f2_a028_11ea_8de1_dc5360e91c1drow1_col4" class="data row1 col4" >15</td>
#                         <td id="T_d91398f2_a028_11ea_8de1_dc5360e91c1drow1_col5" class="data row1 col5" >C</td>
#                         <td id="T_d91398f2_a028_11ea_8de1_dc5360e91c1drow1_col6" class="data row1 col6" >6-11</td>
#                         <td id="T_d91398f2_a028_11ea_8de1_dc5360e91c1drow1_col7" class="data row1 col7" >245</td>
#                         <td id="T_d91398f2_a028_11ea_8de1_dc5360e91c1drow1_col8" class="data row1 col8" >APR 26, 1997</td>
#                         <td id="T_d91398f2_a028_11ea_8de1_dc5360e91c1drow1_col9" class="data row1 col9" >22.00</td>
#                         <td id="T_d91398f2_a028_11ea_8de1_dc5360e91c1drow1_col10" class="data row1 col10" >43</td>
#                         <td id="T_d91398f2_a028_11ea_8de1_dc5360e91c1drow1_col11" class="data row1 col11" >5</td>
#                         <td id="T_d91398f2_a028_11ea_8de1_dc5360e91c1drow1_col12" class="data row1 col12" >446.00</td>
#                         <td id="T_d91398f2_a028_11ea_8de1_dc5360e91c1drow1_col13" class="data row1 col13" >71</td>
#                         <td id="T_d91398f2_a028_11ea_8de1_dc5360e91c1drow1_col14" class="data row1 col14" >171</td>
#                         <td id="T_d91398f2_a028_11ea_8de1_dc5360e91c1drow1_col15" class="data row1 col15" >0.41</td>
#                         <td id="T_d91398f2_a028_11ea_8de1_dc5360e91c1drow1_col16" class="data row1 col16" >22</td>
#                         <td id="T_d91398f2_a028_11ea_8de1_dc5360e91c1drow1_col17" class="data row1 col17" >77</td>
#                         <td id="T_d91398f2_a028_11ea_8de1_dc5360e91c1drow1_col18" class="data row1 col18" >0.29</td>
#                         <td id="T_d91398f2_a028_11ea_8de1_dc5360e91c1drow1_col19" class="data row1 col19" >43</td>
#                         <td id="T_d91398f2_a028_11ea_8de1_dc5360e91c1drow1_col20" class="data row1 col20" >53</td>
#                         <td id="T_d91398f2_a028_11ea_8de1_dc5360e91c1drow1_col21" class="data row1 col21" >0.81</td>
#                         <td id="T_d91398f2_a028_11ea_

# %% [markdown]
# lgtm

# %% [markdown]
# ## Swap Anomaly
#
# Swapping two values in a row (or in a column).
#
# The row based one basically introduces global anomalies. The column based one is another way to introduce dependency anomalies in two places at once.

# %%
df, md = insert_swap_anomaly(
    df,
    row=None,
    l_col=None,
    r_col=None,
    val=None,
    val_list=None,
    val_dist=None,
    rng=None,
    random_state=42,
)

# %%
md
# Out:
# [{'loc': (1, 21), 'old': 0.34700000000000003, 'new': 0.867},
#  {'loc': (1, 18), 'old': 0.867, 'new': 0.34700000000000003}]

# %%
df.head()
# Out:
#   SEASON_ID TEAM_ABBREVIATION  PLAYER_ID                    PLAYER  NUM  \
# 0   2018-19               LAL    1628398                Kyle Kuzma    0
# 1   2018-19               LAL     203484  Kentavious Caldwell-Pope    1
# 2   2018-19               LAL    1628366                Lonzo Ball    2
# 3   2018-19               LAL    1628404                 Josh Hart    3
# 4   2018-19               LAL    1627936               Alex Caruso    4
#
#   POSITION HEIGHT  WEIGHT    BIRTH_DATE  PLAYER_AGE  GP  GS     MIN  FGM  \
# 0        F    6-9     220  JUL 24, 1995        23.0  70  68  2314.0  496
# 1        G    6-5     205  FEB 18, 1993        26.0  82  23  2035.0  325
# 2        G    6-6     190  OCT 27, 1997        21.0  47  45  1423.0  185
# 3        G    6-5     215  MAR 06, 1995        24.0  67  22  1715.0  189
# 4        G    6-5     186  FEB 28, 1994        25.0  25   4   531.0   77
#
#     FGA  FG_PCT  FG3M  FG3A  FG3_PCT  FTM  FTA  FT_PCT  REB  AST  STL  BLK  \
# 0  1087    0.46   128   422     0.30  188  250    0.75  382  178   41   26
# 1   756    0.43   151   435     0.35  137  158    0.87  238  110   73   13
# 2   456    0.41    75   228     0.33   20   48    0.42  251  255   69   19
# 3   464    0.41    92   274     0.34   55   80    0.69  248   93   64   40
# 4   173    0.45    24    50     0.48   51   64    0.80   67   77   24    9
#
#     PTS  a_lbl
# 0  1308      0
# 1   938      0
# 2   465      0
# 3   525      0
# 4   229      0

# %% [markdown]
# ## Transformation Anomaly
#
# Apply a transformation to a value.
#
# This is rather general.
# - Change units (global anomaly)
# - Shift a value (for instance edit a string), can be a global (if you hit a non-existing value) or local (if you end up in a familiar subspace)

# %%
df, md = insert_transformation_anomaly(
    df,
    row=None,
    col="HEIGHT",
    transformation=ft_to_m,
    rng=None,
    random_state=420,
    return_anomaly_metadata=True,
)

# %%
md
# Out:
# {'iloc': (10, 6),
#  'loc': (10, 'HEIGHT'),
#  'old': '6-9',
#  'new': 2.0574000000000003}

# %%
df.tail(7).style.applymap(
    lambda x: "background-color:red", subset=pd.IndexSlice[md["loc"]]
)
# Out:
# <style  type="text/css" >
#     #T_1fff080a_a029_11ea_8de1_dc5360e91c1drow0_col6 {
#             background-color: red;
#         }</style><table id="T_1fff080a_a029_11ea_8de1_dc5360e91c1d" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >SEASON_ID</th>        <th class="col_heading level0 col1" >TEAM_ABBREVIATION</th>        <th class="col_heading level0 col2" >PLAYER_ID</th>        <th class="col_heading level0 col3" >PLAYER</th>        <th class="col_heading level0 col4" >NUM</th>        <th class="col_heading level0 col5" >POSITION</th>        <th class="col_heading level0 col6" >HEIGHT</th>        <th class="col_heading level0 col7" >WEIGHT</th>        <th class="col_heading level0 col8" >BIRTH_DATE</th>        <th class="col_heading level0 col9" >PLAYER_AGE</th>        <th class="col_heading level0 col10" >GP</th>        <th class="col_heading level0 col11" >GS</th>        <th class="col_heading level0 col12" >MIN</th>        <th class="col_heading level0 col13" >FGM</th>        <th class="col_heading level0 col14" >FGA</th>        <th class="col_heading level0 col15" >FG_PCT</th>        <th class="col_heading level0 col16" >FG3M</th>        <th class="col_heading level0 col17" >FG3A</th>        <th class="col_heading level0 col18" >FG3_PCT</th>        <th class="col_heading level0 col19" >FTM</th>        <th class="col_heading level0 col20" >FTA</th>        <th class="col_heading level0 col21" >FT_PCT</th>        <th class="col_heading level0 col22" >REB</th>        <th class="col_heading level0 col23" >AST</th>        <th class="col_heading level0 col24" >STL</th>        <th class="col_heading level0 col25" >BLK</th>        <th class="col_heading level0 col26" >PTS</th>        <th class="col_heading level0 col27" >a_lbl</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_1fff080a_a029_11ea_8de1_dc5360e91c1dlevel0_row0" class="row_heading level0 row0" >10</th>
#                         <td id="T_1fff080a_a029_11ea_8de1_dc5360e91c1drow0_col0" class="data row0 col0" >2018-19</td>
#                         <td id="T_1fff080a_a029_11ea_8de1_dc5360e91c1drow0_col1" class="data row0 col1" >LAL</td>
#                         <td id="T_1fff080a_a029_11ea_8de1_dc5360e91c1drow0_col2" class="data row0 col2" >1627742</td>
#                         <td id="T_1fff080a_a029_11ea_8de1_dc5360e91c1drow0_col3" class="data row0 col3" >Brandon Ingram</td>
#                         <td id="T_1fff080a_a029_11ea_8de1_dc5360e91c1drow0_col4" class="data row0 col4" >14</td>
#                         <td id="T_1fff080a_a029_11ea_8de1_dc5360e91c1drow0_col5" class="data row0 col5" >F</td>
#                         <td id="T_1fff080a_a029_11ea_8de1_dc5360e91c1drow0_col6" class="data row0 col6" >2.06</td>
#                         <td id="T_1fff080a_a029_11ea_8de1_dc5360e91c1drow0_col7" class="data row0 col7" >190</td>
#                         <td id="T_1fff080a_a029_11ea_8de1_dc5360e91c1drow0_col8" class="data row0 col8" >SEP 02, 1997</td>
#                         <td id="T_1fff080a_a029_11ea_8de1_dc5360e91c1drow0_col9" class="data row0 col9" >28.00</td>
#                         <td id="T_1fff080a_a029_11ea_8de1_dc5360e91c1drow0_col10" class="data row0 col10" >52</td>
#                         <td id="T_1fff080a_a029_11ea_8de1_dc5360e91c1drow0_col11" class="data row0 col11" >52</td>
#                         <td id="T_1fff080a_a029_11ea_8de1_dc5360e91c1drow0_col12" class="data row0 col12" >1761.00</td>
#                         <td id="T_1fff080a_a029_11ea_8de1_dc5360e91c1drow0_col13" class="data row0 col13" >362</td>
#                         <td id="T_1fff080a_a029_11ea_8de1_dc5360e91c1drow0_col14" class="data row0 col14" >729</td>
#                         <td id="T_1fff080a_a029_11ea_8de1_dc5360e91c1drow0_col15" class="data row0 col15" >0.50</td>
#                         <td id="T_1fff080a_a029_11ea_8de1_dc5360e91c1drow0_col16" class="data row0 col16" >31</td>
#                         <td id="T_1fff080a_a029_11ea_8de1_dc5360e91c1drow0_col17" class="data row0 col17" >94</td>
#                         <td id="T_1fff080a_a029_11ea_8de1_dc5360e91c1drow0_col18" class="data row0 col18" >0.33</td>
#                         <td id="T_1fff080a_a029_11ea_8de1_dc5360e91c1drow0_col19" class="data row0 col19" >195</td>
#                         <td id="T_1fff080a_a029_11ea_8de1_dc5360e91c1drow0_col20" class="data row0 col20" >289</td>
#                         <td id="T_1fff080a_a029_11ea_8de1_dc5360e91c1drow0_col21" class="data row0 col21" >0.68</td>
#                         <td id="T_1fff080a_a029_11ea_8de1_dc5360e91c1drow0_col22" class="data row0 col22" >267</td>
#                         <td id="T_1fff080a_a029_11ea_8de1_dc5360e91c1drow0_col23" class="data row0 col23" >154</td>
#                         <td id="T_1fff080a_a029_11ea_8de1_dc5360e91c1drow0_col24" class="data row0 col24" >28</td>
#                         <td id="T_1fff080a_a029_11ea_8de1_dc5360e91c1drow0_col25" class="data row0 col25" >31</td>
#                         <td id="T_1fff080a_a029_11ea_8de1_dc5360e91c1drow0_col26" class="data row0 col26" >950</td>
#                         <td id="T_1fff080a_a029_11ea_8de1_dc5360e91c1drow0_col27" class="data row0 col27" >1</td>
#             </tr>
#             <tr>
#                         <th id="T_1fff080a_a029_11ea_8de1_dc5360e91c1dlevel0_row1" class="row_heading level0 row1" >11</th>
#                         <td id="T_1fff080a_a029_11ea_8de1_dc5360e91c1drow1_col0" class="data row1 col0" >2018-19</td>
#                         <td id="T_1fff080a_a029_11ea_8de1_dc5360e91c1drow1_col1" class="data row1 col1" >LAL</td>
#                         <td id="T_1fff080a_a029_11ea_8de1_dc5360e91c1drow1_col2" class="data row1 col2" >1629021</td>
#                         <td id="T_1fff080a_a029_11ea_8de1_dc5360e91c1drow1_col3" class="data row1 col3" >Moritz Wagner</td>
#                         <td id="T_1fff080a_a029_11ea_8de1_dc5360e91c1drow1_col4" class="data row1 col4" >15</td>
#                         <td id="T_1fff080a_a029_11ea_8de1_dc5360e91c1drow1_col5" class="data row1 col5" >C</td>
#                         <td id="T_1fff080a_a029_11ea_8de1_dc5360e91c1drow1_col6" class="data row1 col6" >6-11</td>
#                         <td id="T_1fff080a_a029_11ea_8de1_dc5360e91c1drow1_col7" class="data row1 col7" >245</td>
#                         <td id="T_1fff080a_a029_11ea_8de1_dc5360e91c1drow1_col8" class="data row1 col8" >APR 26, 1997</td>
#                         <td id="T_1fff080a_a029_11ea_8de1_dc5360e91c1drow1_col9" class="data row1 col9" >22.00</td>
#                         <td id="T_1fff080a_a029_11ea_8de1_dc5360e91c1drow1_col10" class="data row1 col10" >43</td>
#                         <td id="T_1fff080a_a029_11ea_8de1_dc5360e91c1drow1_col11" class="data row1 col11" >5</td>
#                         <td id="T_1fff080a_a029_11ea_8de1_dc5360e91c1drow1_col12" class="data row1 col12" >446.00</td>
#                         <td id="T_1fff080a_a029_11ea_8de1_dc5360e91c1drow1_col13" class="data row1 col13" >71</td>
#                         <td id="T_1fff080a_a029_11ea_8de1_dc5360e91c1drow1_col14" class="data row1 col14" >171</td>
#                         <td id="T_1fff080a_a029_11ea_8de1_dc5360e91c1drow1_col15" class="data row1 col15" >0.41</td>
#                         <td id="T_1fff080a_a029_11ea_8de1_dc5360e91c1drow1_col16" class="data row1 col16" >22</td>
#                         <td id="T_1fff080a_a029_11ea_8de1_dc5360e91c1drow1_col17" class="data row1 col17" >77</td>
#                         <td id="T_1fff080a_a029_11ea_8de1_dc5360e91c1drow1_col18" class="data row1 col18" >0.29</td>
#                         <td id="T_1fff080a_a029_11ea_8de1_dc5360e91c1drow1_col19" class="data row1 col19" >43</td>
#                         <td id="T_1fff080a_a029_11ea_8de1_dc5360e91c1drow1_col20" class="data row1 col20" >53</td>
#                         <td id="T_1fff080a_a029_11ea_8de1_dc5360e91c1drow1_col21" class="data row1 col21" >0.81</td>
#                         <td id="T_1fff080a_a029_11ea

# %% [markdown]
# ## Contextual Anomaly
#
# Introduce an anomaly in a subpopulation. This is not a global one, and also not really a local one (if it is situated in a single feature, even local metrics may fail to detect.)
#
# This is a higher level anomaly, for instance you can replace a guard's height with a height sampled from the centers. In that way, it may actually be difficult to detect for global methods, but in the subpopulation of guards, it should really be a big outlier.
#
# Re-use previous methods which you derived above. Finalize this asap!
#
# Also, write your demo-DataFrame to disk.

# %%
df, md = insert_contextual_anomaly(
    df,
    row=None,
    col="HEIGHT",
    src_subpop_filter=lambda r: r.POSITION == "C",
    tgt_subpop_filter=lambda r: r.POSITION == "G",
    rng=None,
    random_state=40,
    return_anomaly_metadata=True,
)
# Out:
# ['7-1' '7-0' '6-11']

# %%
md
# Out:
# {'iloc': (8, 6), 'loc': (8, 'HEIGHT'), 'old': '6-1', 'new': '7-0'}

# %%
df.head(5).style.applymap(
    lambda x: "background-color:orange", subset=pd.IndexSlice[md["loc"]]
)
# Out:
# <style  type="text/css" >
#     #T_36e15b86_a029_11ea_8de1_dc5360e91c1drow4_col6 {
#             background-color: orange;
#         }</style><table id="T_36e15b86_a029_11ea_8de1_dc5360e91c1d" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >SEASON_ID</th>        <th class="col_heading level0 col1" >TEAM_ABBREVIATION</th>        <th class="col_heading level0 col2" >PLAYER_ID</th>        <th class="col_heading level0 col3" >PLAYER</th>        <th class="col_heading level0 col4" >NUM</th>        <th class="col_heading level0 col5" >POSITION</th>        <th class="col_heading level0 col6" >HEIGHT</th>        <th class="col_heading level0 col7" >WEIGHT</th>        <th class="col_heading level0 col8" >BIRTH_DATE</th>        <th class="col_heading level0 col9" >PLAYER_AGE</th>        <th class="col_heading level0 col10" >GP</th>        <th class="col_heading level0 col11" >GS</th>        <th class="col_heading level0 col12" >MIN</th>        <th class="col_heading level0 col13" >FGM</th>        <th class="col_heading level0 col14" >FGA</th>        <th class="col_heading level0 col15" >FG_PCT</th>        <th class="col_heading level0 col16" >FG3M</th>        <th class="col_heading level0 col17" >FG3A</th>        <th class="col_heading level0 col18" >FG3_PCT</th>        <th class="col_heading level0 col19" >FTM</th>        <th class="col_heading level0 col20" >FTA</th>        <th class="col_heading level0 col21" >FT_PCT</th>        <th class="col_heading level0 col22" >REB</th>        <th class="col_heading level0 col23" >AST</th>        <th class="col_heading level0 col24" >STL</th>        <th class="col_heading level0 col25" >BLK</th>        <th class="col_heading level0 col26" >PTS</th>        <th class="col_heading level0 col27" >a_lbl</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_36e15b86_a029_11ea_8de1_dc5360e91c1dlevel0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_36e15b86_a029_11ea_8de1_dc5360e91c1drow0_col0" class="data row0 col0" >2018-19</td>
#                         <td id="T_36e15b86_a029_11ea_8de1_dc5360e91c1drow0_col1" class="data row0 col1" >LAL</td>
#                         <td id="T_36e15b86_a029_11ea_8de1_dc5360e91c1drow0_col2" class="data row0 col2" >1628398</td>
#                         <td id="T_36e15b86_a029_11ea_8de1_dc5360e91c1drow0_col3" class="data row0 col3" >Kyle Kuzma</td>
#                         <td id="T_36e15b86_a029_11ea_8de1_dc5360e91c1drow0_col4" class="data row0 col4" >0</td>
#                         <td id="T_36e15b86_a029_11ea_8de1_dc5360e91c1drow0_col5" class="data row0 col5" >F</td>
#                         <td id="T_36e15b86_a029_11ea_8de1_dc5360e91c1drow0_col6" class="data row0 col6" >6-9</td>
#                         <td id="T_36e15b86_a029_11ea_8de1_dc5360e91c1drow0_col7" class="data row0 col7" >220</td>
#                         <td id="T_36e15b86_a029_11ea_8de1_dc5360e91c1drow0_col8" class="data row0 col8" >JUL 24, 1995</td>
#                         <td id="T_36e15b86_a029_11ea_8de1_dc5360e91c1drow0_col9" class="data row0 col9" >23.00</td>
#                         <td id="T_36e15b86_a029_11ea_8de1_dc5360e91c1drow0_col10" class="data row0 col10" >70</td>
#                         <td id="T_36e15b86_a029_11ea_8de1_dc5360e91c1drow0_col11" class="data row0 col11" >68</td>
#                         <td id="T_36e15b86_a029_11ea_8de1_dc5360e91c1drow0_col12" class="data row0 col12" >2314.00</td>
#                         <td id="T_36e15b86_a029_11ea_8de1_dc5360e91c1drow0_col13" class="data row0 col13" >496</td>
#                         <td id="T_36e15b86_a029_11ea_8de1_dc5360e91c1drow0_col14" class="data row0 col14" >1087</td>
#                         <td id="T_36e15b86_a029_11ea_8de1_dc5360e91c1drow0_col15" class="data row0 col15" >0.46</td>
#                         <td id="T_36e15b86_a029_11ea_8de1_dc5360e91c1drow0_col16" class="data row0 col16" >128</td>
#                         <td id="T_36e15b86_a029_11ea_8de1_dc5360e91c1drow0_col17" class="data row0 col17" >422</td>
#                         <td id="T_36e15b86_a029_11ea_8de1_dc5360e91c1drow0_col18" class="data row0 col18" >0.30</td>
#                         <td id="T_36e15b86_a029_11ea_8de1_dc5360e91c1drow0_col19" class="data row0 col19" >188</td>
#                         <td id="T_36e15b86_a029_11ea_8de1_dc5360e91c1drow0_col20" class="data row0 col20" >250</td>
#                         <td id="T_36e15b86_a029_11ea_8de1_dc5360e91c1drow0_col21" class="data row0 col21" >0.75</td>
#                         <td id="T_36e15b86_a029_11ea_8de1_dc5360e91c1drow0_col22" class="data row0 col22" >382</td>
#                         <td id="T_36e15b86_a029_11ea_8de1_dc5360e91c1drow0_col23" class="data row0 col23" >178</td>
#                         <td id="T_36e15b86_a029_11ea_8de1_dc5360e91c1drow0_col24" class="data row0 col24" >41</td>
#                         <td id="T_36e15b86_a029_11ea_8de1_dc5360e91c1drow0_col25" class="data row0 col25" >26</td>
#                         <td id="T_36e15b86_a029_11ea_8de1_dc5360e91c1drow0_col26" class="data row0 col26" >1308</td>
#                         <td id="T_36e15b86_a029_11ea_8de1_dc5360e91c1drow0_col27" class="data row0 col27" >0</td>
#             </tr>
#             <tr>
#                         <th id="T_36e15b86_a029_11ea_8de1_dc5360e91c1dlevel0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_36e15b86_a029_11ea_8de1_dc5360e91c1drow1_col0" class="data row1 col0" >2018-19</td>
#                         <td id="T_36e15b86_a029_11ea_8de1_dc5360e91c1drow1_col1" class="data row1 col1" >LAL</td>
#                         <td id="T_36e15b86_a029_11ea_8de1_dc5360e91c1drow1_col2" class="data row1 col2" >203484</td>
#                         <td id="T_36e15b86_a029_11ea_8de1_dc5360e91c1drow1_col3" class="data row1 col3" >Kentavious Caldwell-Pope</td>
#                         <td id="T_36e15b86_a029_11ea_8de1_dc5360e91c1drow1_col4" class="data row1 col4" >1</td>
#                         <td id="T_36e15b86_a029_11ea_8de1_dc5360e91c1drow1_col5" class="data row1 col5" >G</td>
#                         <td id="T_36e15b86_a029_11ea_8de1_dc5360e91c1drow1_col6" class="data row1 col6" >6-5</td>
#                         <td id="T_36e15b86_a029_11ea_8de1_dc5360e91c1drow1_col7" class="data row1 col7" >205</td>
#                         <td id="T_36e15b86_a029_11ea_8de1_dc5360e91c1drow1_col8" class="data row1 col8" >FEB 18, 1993</td>
#                         <td id="T_36e15b86_a029_11ea_8de1_dc5360e91c1drow1_col9" class="data row1 col9" >26.00</td>
#                         <td id="T_36e15b86_a029_11ea_8de1_dc5360e91c1drow1_col10" class="data row1 col10" >82</td>
#                         <td id="T_36e15b86_a029_11ea_8de1_dc5360e91c1drow1_col11" class="data row1 col11" >23</td>
#                         <td id="T_36e15b86_a029_11ea_8de1_dc5360e91c1drow1_col12" class="data row1 col12" >2035.00</td>
#                         <td id="T_36e15b86_a029_11ea_8de1_dc5360e91c1drow1_col13" class="data row1 col13" >325</td>
#                         <td id="T_36e15b86_a029_11ea_8de1_dc5360e91c1drow1_col14" class="data row1 col14" >756</td>
#                         <td id="T_36e15b86_a029_11ea_8de1_dc5360e91c1drow1_col15" class="data row1 col15" >0.43</td>
#                         <td id="T_36e15b86_a029_11ea_8de1_dc5360e91c1drow1_col16" class="data row1 col16" >151</td>
#                         <td id="T_36e15b86_a029_11ea_8de1_dc5360e91c1drow1_col17" class="data row1 col17" >435</td>
#                         <td id="T_36e15b86_a029_11ea_8de1_dc5360e91c1drow1_col18" class="data row1 col18" >0.35</td>
#                         <td id="T_36e15b86_a029_11ea_8de1_dc5360e91c1drow1_col19" class="data row1 col19" >137</td>
#                         <td id="T_36e15b86_a029_11ea_8de1_dc5360e91c1drow1_col20" class="data row1 col20" >158</td>
#                         <td id="T_36e15b86_a029_11ea_8de1_dc5360e91c1drow1_col21" class="data row1 col21" >0.87</td>
#                         <td id="T_36e1

# %% [markdown]
# So this looks rather good to me, and all the power of the subpopulations is in the filers so there you can in principle go unlimited. Now the point is that you need to document your efforts and get this into actual datasets.
#
# - Datasets
# - Spreadsheets
# - Demos
#     - Does ADMERCS work
#     - Can you get ADMERCS in Synth?
#     - Can Synth do other cool stuff on these datasets?

# %% [markdown]
# # Create Datasets
#
# Apply all the above the generate some actual datasets.

# %% [markdown]
# # SpreadSheet
#
# For Synth, convert to spreadsheets useable in the Synth framework.

# %%
import openpyxl

# %%
with pd.ExcelWriter("output.xlsx") as writer:
    df.to_excel(
        writer, startrow=0, startcol=0, index=False, sheet_name="anomaly_detection"
    )
